# %% [markdown]
# # Analyzing my Amazon's Order History Report
# > "Fun data science practice with personal dataset."
#
#
# - toc:false
# - branch: master
# - badges: true
# - hide: true
# - comments: true
# - author: Ev Horrosh
# - image: images/Order-History-Report.png

# %% [markdown]
# ![Order History Report.png](data:image/png;base64,...)

# %% [markdown]
# # Agenda
#
# Practicing Data Science is essential. Having a custom dataset makes your portfolio interesting to explore.
#
# Here's an idea, how about checking out your amazon's order history report for a year?
#
# That's what I'm going do.
# Who knows what we can find.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
data={'cars':['toyota','subaru','nissan','honda'],
      'price':[3200,2800,2400,1750],
      'features':[24,20,18,30],
      'colors':['red','white','blue','black'],
      'doors':[4,5,4,2]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#      cars  price  features colors  doors
# 0  toyota   3200        24    red      4
# 1  subaru   2800        20  white      5
# 2  nissan   2400        18   blue      4
# 3   honda   1750        30  black      2

# %%
for label, content in df.items():
  if pd.api.types.is_string_dtype(content):
    df[label]=content.astype('category').cat.as_ordered()

# %%
# X=df.drop(['price'],axis=1)
# X.info()
X=df[['doors','features']]

# %%
y=df['price']

# %%
X_train, x_test, y_train, y_test=train_test_split(X,y,test_size=.2,random_state=42)

# %%
y_test
# Out:
# 1    2800
# Name: price, dtype: int64

# %%
lr=LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.score(X,y)
# predict=lr.predict()
lr.coef_
# Out:
# array([638.18181818,  70.22727273])

# %%
def sum_of_sq(X):
  avg=X.mean()
  X_=[np.square(i-avg) for i in X]
  return sum(X_)

# %%
med=np.asarray([12,11,54,73,22,1,3])

# %%
sum_of_sq(med)
# Out:
# 4578.857142857143

# %%
np.ss(np.square([2,2,2]))
# Out:
# 12

# %%
954/21
# Out:
# 45.42857142857143

# %%
np.corrcoef(df['price'],df['doors'])
# Out:
# array([[1.        , 0.78726782],
#        [0.78726782, 1.        ]])

# %%
plt.scatter(df['p'])

# %%
np.mean(np.asarray([1,2,2,2,0,3,3,3,5,2,1,1,1,1,1]))
# Out:
# 1.8666666666666667
